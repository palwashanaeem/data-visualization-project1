# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
cars_df=pd.read_excel(r"C:\Users\Useer\Downloads\Automobile (2).xlsx")
cars_df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
#Feature Scaling
numerical_features = cars_df.select_dtypes(include=['int64', 'float64']).columns
print("\nNumerical Columns:")
print(numerical_features)
# Out:
# Numerical Columns:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year'],
#       dtype='object')

# %%
for column in numerical_features:
    column_range = cars_df[column].max() - cars_df[column].min()
    print(f"Range of '{column}': {column_range}")
# Out:
# Range of 'mpg': 37.6
# Range of 'cylinders': 5
# Range of 'displacement': 387.0
# Range of 'horsepower': 184.0
# Range of 'weight': 3527
# Range of 'acceleration': 16.8
# Range of 'model_year': 12

# %%
features_to_scale = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year']
cars_df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
scaler_minmax = MinMaxScaler()
df_minmax_scaled = pd.DataFrame(scaler_minmax.fit_transform(cars_df[features_to_scale]), columns=features_to_scale)
print("\nDataset After Min-Max Scaling:")
df_minmax_scaled
# Out:
# Dataset After Min-Max Scaling:
#           mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0    0.239362        1.0      0.617571    0.456522  0.536150      0.238095
# 1    0.159574        1.0      0.728682    0.646739  0.589736      0.208333
# 2    0.239362        1.0      0.645995    0.565217  0.516870      0.178571
# 3    0.186170        1.0      0.609819    0.565217  0.516019      0.238095
# 4    0.212766        1.0      0.604651    0.510870  0.520556      0.148810
# ..        ...        ...           ...         ...       ...           ...
# 393  0.478723        0.2      0.186047    0.217391  0.333711      0.452381
# 394  0.930851        0.2      0.074935    0.032609  0.146583      0.988095
# 395  0.611702        0.2      0.173127    0.206522  0.193365      0.214286
# 396  0.505319        0.2      0.134367    0.179348  0.286929      0.630952
# 397  0.585106        0.2      0.131783    0.195652  0.313864      0.678571
#
#      model_year
# 0           0.0
# ...

# %%
#['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year']
print("\nOriginal Dataset:")
cars_df[features_to_scale]
# Out:
# Original Dataset:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.boxplot(df_standard_scaled.values, vert=False, patch_artist=True)


plt.title('Box Plot of Standardized Features')
plt.xlabel('Standardized Values (Z-scores)')
plt.ylabel('Features')



# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_standard_scaled, orient='h')
plt.title('Box Plot of Standardized Features')
plt.xlabel('Standardized Values (Z-scores)')
plt.ylabel('Features')
plt.show()

# %%
print("\nMax Value of 'mpg' in Original Dataset:")
cars_df['mpg'].max()
# Out:
# Max Value of 'mpg' in Original Dataset:
# 46.6

# %%
print("\nMax Value of 'cylinders' in Original Dataset:")
cars_df['cylinders'].max()
# Out:
# Max Value of 'cylinders' in Original Dataset:
# 8

# %%
print("\nMax Value of 'displacement' in Original Dataset:")
cars_df['displacement'].max()
# Out:
# Max Value of 'displacement' in Original Dataset:
# 455.0

# %%
print("\nMax Value of 'horsepower' in Original Dataset:")
cars_df['horsepower'].max()
# Out:
# Max Value of 'horsepower' in Original Dataset:
# 230.0

# %%
print("\nMax Value of 'weight' in Original Dataset:")
cars_df['weight'].max()
# Out:
# Max Value of 'weight' in Original Dataset:
# 5140

# %%
print("\nMax Value of 'acceleration' in Original Dataset:")
cars_df['acceleration'].max()
# Out:
# Max Value of 'acceleration' in Original Dataset:
# 24.8

# %%
print("\nMax Value of 'model_year' in Original Dataset:")
cars_df['model_year'].max()
# Out:
# Max Value of 'model_year' in Original Dataset:
# 82

# %%
 #Standardization using StandardScaler
scaler_standard = StandardScaler()
df_standard_scaled = pd.DataFrame(scaler_standard.fit_transform(cars_df[features_to_scale]), columns=features_to_scale)
print("\nDataset After Standardization (Z-score Normalization):")
df_standard_scaled
# Out:
# Dataset After Standardization (Z-score Normalization):
#           mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0   -0.706439   1.498191      1.090604    0.664133  0.630870     -1.295498
# 1   -1.090751   1.498191      1.503514    1.574594  0.854333     -1.477038
# 2   -0.706439   1.498191      1.196232    1.184397  0.550470     -1.658577
# 3   -0.962647   1.498191      1.061796    1.184397  0.546923     -1.295498
# 4   -0.834543   1.498191      1.042591    0.924265  0.565841     -1.840117
# ..        ...        ...           ...         ...       ...           ...
# 393  0.446497  -0.856321     -0.513026   -0.480448 -0.213324      0.011586
# 394  2.624265  -0.856321     -0.925936   -1.364896 -0.993671      3.279296
# 395  1.087017  -0.856321     -0.561039   -0.532474 -0.798585     -1.440730
# 396  0.574601  -0.856321     -0.705077   -0.662540 -0.408411      1.100822
# 397  0.958913  -0.856321     -0.714680   -0.584501 -0.296088      1.391285
#
# ...

# %%
print("\nOriginal Dataset:")
cars_df[features_to_scale]
# Out:
# Original Dataset:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ...

# %%
cars_df[features_to_scale] = df_standard_scaled
print("\nUpdated Dataset:")
cars_df[features_to_scale]
# Out:
# Updated Dataset:
#           mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0   -0.706439   1.498191      1.090604    0.664133  0.630870     -1.295498
# 1   -1.090751   1.498191      1.503514    1.574594  0.854333     -1.477038
# 2   -0.706439   1.498191      1.196232    1.184397  0.550470     -1.658577
# 3   -0.962647   1.498191      1.061796    1.184397  0.546923     -1.295498
# 4   -0.834543   1.498191      1.042591    0.924265  0.565841     -1.840117
# ..        ...        ...           ...         ...       ...           ...
# 393  0.446497  -0.856321     -0.513026   -0.480448 -0.213324      0.011586
# 394  2.624265  -0.856321     -0.925936   -1.364896 -0.993671      3.279296
# 395  1.087017  -0.856321     -0.561039   -0.532474 -0.798585     -1.440730
# 396  0.574601  -0.856321     -0.705077   -0.662540 -0.408411      1.100822
# 397  0.958913  -0.856321     -0.714680   -0.584501 -0.296088      1.391285
#
#      model_year
# 0     -1.627426
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_standard_scaled)


plt.title('Box Plot of Standardized Features')
plt.xticks(rotation=90)  # Rotate feature names if needed


plt.show()
